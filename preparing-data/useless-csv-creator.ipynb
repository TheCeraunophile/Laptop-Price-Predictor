# %%
file = open('useless-features')
# read the file data
result = file.read()
# convert it's format to csv format
finnal_features = result.split('\n')

import pandas as pd
# save the useless columns as a csv file
pd.DataFrame(finnal_features).to_csv('useless_features.csv')

# %%
import pandas as pd
import numpy as np

file = open('merge-features-together (copy)')
# read the file data
result = file.read()
# convert it's format to csv format
finnal_features = result.split('\n')

# save the useless columns as a csv file
df = pd.DataFrame(finnal_features).to_csv('merge-feature.csv')

df = pd.read_csv('merge-feature.csv')
df['0'] = df['0'].fillna('/')
df.to_csv('merge-feature.csv')
df
# Out:
#      Unnamed: 0                          0
# 0             0                 سری لپ تاپ
# 1             1                        مدل
# 2             2           نوع و مدل لپ تاپ
# 3             3                          /
# 4             4                   نام برند
# ..          ...                        ...
# 378         378            سنسور اثر انگشت
# 379         379  حسگر اثر انگشت (Touch ID)
# 380         380         اثر انگشت (Finger)
# 381         381    حسگر اثر انگشت Touch ID
# 382         382                          /
#
# [383 rows x 2 columns]
